# %%
import pyttsx3
import datetime
import speech_recognition 
import webbrowser
import os
import time
import winsound
eng=pyttsx3.init('sapi5')
eng.setProperty("rate", 350)
voices=eng.getProperty('voices')
# print(voices[2].id)
eng.setProperty('voice',voices[1].id)

def speak(audio):
    eng.say(audio)
    eng.runAndWait()#Without this command the speech will not be audible to us
def wishMe():
    hour=int(datetime.datetime.now().hour)
    eng.setProperty("rate", 170)
    if(hour>=0 and hour<12):
        speak("Good Morning Boss")
    elif(hour>=12 and hour<18):
        speak("Good evening Boss")
    elif(hour>=18 and hour<24):
        if(hour>=22):
            speak("Hey boss, Clock Crossed the 10 PM")
            if(hour>=23):
                speak("Boss,Please sleep now,Do remaining work tommorow!")
        
def takeCommand():
    recogniz=speech_recognition.Recognizer()
    winsound.Beep(7000, 500)
    with speech_recognition.Microphone() as source:
        print("Listening  ....")
        recogniz.pause_threshold=0.5
        audio=recogniz.listen(source)
    try:
        print("Recognizing  ....")
        query=recogniz.recognize_google(audio,language='en-in')
        print(query,"\n")
    except :
        winsound.PlaySound("SystemQuestion", winsound.SND_ALIAS) 
        speak("Can you repeat ?")
        return "Unknow"
        
    return query

def takeCommandSleep():
    # This is the command function in case of sleep of program ,but it still listening!
    recogniz=speech_recognition.Recognizer()
    with speech_recognition.Microphone() as source:
        recogniz.pause_threshold=0.5
        audio=recogniz.listen(source)
    try:
        query=recogniz.recognize_google(audio,language='en-in')
    except :
        return "Unknow"
        
    return query

def webService():
    while(True):
        query=takeCommand()
        query=query.lower()
        reason="Link is not working. Please check" # If link is not working then this is the result
        if( "youtube" in query ):
            try:
                webbrowser.open("https://www.youtube.com/")
            except:
                speak(reason)
        if( "facebook" in query ):
            try:
                webbrowser.open("https://www.facebook.com/")
            except:
                speak(reason)
        if( "instagram" in query ):
            try:
                webbrowser.open("https://www.instagram.com/")
            except:
                speak(reason)
        if( "stack overflow" in query ):
            try:
                webbrowser.open("https://stackoverflow.com/")
            except:
                speak(reason)
        if( "geeks for geeks" in query ) or ( "gfg" in query ):
            try:
                webbrowser.open("https://practice.geeksforgeeks.org/topic-tags/#")
            except:
                speak(reason)

        if( "classroom" in query ):
            try:
                webbrowser.open('https://classroom.google.com/u/1/h')
            except:
                speak(reason)
        if( "code wars" in query ):
            try:
                webbrowser.open("https://www.codewars.com/dashboard")
            except:
                speak(reason)
        if "www" in query or "com" in query:
            try:
                webbrowser.open("http://"+query+"/")
            except:
                speak(reason)
        if( "sleep jarvis" in query  or "sleep" in query):
            speak("Sleeping ....")
            while(True):
                awake=takeCommandSleep()
                awake=awake.lower()
                if(("wake up" in query) or ("active" in awake)or ("awake" in awake)):
                    speech_recognition.Recognizer().energy_threshold=300
                    speak("Active and ready sir! ")
                    break
        if "exit" in query or "quit" in query :
            speak("Quiting from web Service ")
            winsound.PlaySound("SystemExit", winsound.SND_ALIAS)
            break
        winsound.Beep(700, 500)
    
        
def systemService():
    while(True):
        query=takeCommand()
        query=query.lower()
        if "code" in query:
            winsound.Beep(700, 500)
            try:
                os.startfile("C:\\Users\\HP\\AppData\\Local\Programs\\Microsoft VS Code\\Code.exe")
            except:
                speak("Content is not present ,At specified addresss")
        if "whatsapp" in query:
            winsound.Beep(700, 500)
            try:
                os.startfile("C:\\Users\\HP\\OneDrive\\Desktop\\WhatsApp.lnk")
            except:
                speak("Content is not present ,At specified addresss")
            
        if ("prime video" in query) or ("open amazon prime" in query):
            winsound.Beep(700, 500)
            try:
                os.startfile("C:\\Users\\HP\\OneDrive\\Desktop\\Amazon Prime Video for Windows.lnk")
            except:
                speak("Content is not present ,At specified addresss")
        if "discord" in query:
            winsound.Beep(700, 500)
            try:
                os.startfile("C:\\Users\\HP\\OneDrive\\Desktop\Discord.lnk")
            except:
                speak("Content is not present ,At specified addresss")
        if ("node js" in query) or ("open node" in query):
            winsound.Beep(700, 500)
            try:
                os.startfile("C:\\Program Files\\nodejs\\node.exe")
            except:
                speak("Content is not present ,At specified addresss")
        if "terminal" in query :
            winsound.Beep(700, 500)
            try:
                os.startfile("C:\\Users\\HP\\OneDrive\\Desktop\\Windows Terminal.lnk")
            except:
                speak("Content is not present ,At specified addresss")
        if "ubuntu" in query or "linux" in query :
            winsound.Beep(700, 500)
            try:
                os.startfile("C:\\Users\\HP\\OneDrive\\Desktop\\Ubuntu.lnk")
            except:
                speak("Content is not present ,At specified addresss")
    
        if "music" in query :
            winsound.Beep(700, 500)
            try:
                os.startfile("C:\\Users\\HP\\OneDrive\\Desktop\Discord (2).lnk")
            except:
                speak("Content is not present ,At specified addresss")
        if "camera" in query:
            winsound.Beep(700, 500)
            try:
                os.startfile("C:\\Users\\HP\\OneDrive\\Desktop\Camera.lnk")
            except:
                speak("Content is not present ,At specified addresss")
        if "clock" in query :
            winsound.Beep(700, 500)
            try:
                os.startfile("C:\\Users\\HP\\OneDrive\\Desktop\\Clock.lnk")
            except:
                speak("Content is not present ,At specified addresss")
        if "calculator" in query :
            winsound.Beep(700, 500)
            try:
                os.startfile("C:\\Users\\HP\\OneDrive\\Desktop\\Calculator.lnk")
            except:
                speak("Content is not present ,At specified addresss")
        if "settings" in query :
            winsound.Beep(700, 500)
            try:
                os.startfile("C:\\Users\\HP\\OneDrive\\Desktop\\Settings.lnk")
            except:
                speak("Content is not present ,At specified addresss")
        if "www" in query or "com" in query:
            try:
                webbrowser.open("http://"+query)
            except:
                speak("Content is not present ,At specified addresss")
        
        if( "sleep jarvis" in query  or "sleep" in query):
            speak("Sleeping ....")
            while(True):
                awake=takeCommandSleep()
                awake=awake.lower()
                if(("wake up" in query) or ("active" in awake)or ("awake" in awake)):
                    speech_recognition.Recognizer().energy_threshold=300
                    speak("Active and ready sir! ")
                    break
        if "exit" in query or "quit" in query :
            speak("Quiting from System Service ")
            winsound.PlaySound("SystemExit", winsound.SND_ALIAS)
            break
        

def study():
    while(True):
        query=takeCommand()
        query=query.lower()
        if ("toc" in query) or ("theory of computation" in query):
            winsound.Beep(700, 500)
            os.startfile("C:\\Users\\HP\Downloads\\Introduction to automata theory.pdf")

        if ("data structures" in query) or("dsa" in query):
            winsound.Beep(700, 500)
            os.startfile("C:\\Users\\HP\Downloads\\Introduction to algorithms by Thomas H. Cormen, Charles E. Leiserson, Ronald L. Rivest, Clifford Stein (z-lib.org).pdf")
        if ("statistics" in query) or("math" in query):
            os.startfile("C:\\Users\\HP\\Downloads\\Fundamentals of Mathematical Statistics by S. C. Gupta and V.K. Kapoor.pdf")
        
        if ("os" in query) or ("operating system" in query):
            winsound.Beep(700, 500)
            if("notes" in query):
                os.startfile("C:\\Users\\HP\\Downloads\\Mod 1_LN.pdf")
            else:
                os.startfile("C:\\Users\\HP\\Downloads\\lecture1423726024.pdf")
        if( "sleep jarvis" in query  or "sleep" in query):
            speak("Sleeping ....")
            while(True):
                awake=takeCommandSleep()
                awake=awake.lower()
                if(("wake up" in query) or ("active" in awake)or ("awake" in awake)):
                    speech_recognition.Recognizer().energy_threshold=300
                    speak("Active and ready sir! ")
                    break
        if ("exit" in query) or ("quit" in query) :
            speak("Quiting from Study Service ")
            winsound.PlaySound("SystemExit", winsound.SND_ALIAS)
            break
        

        

if __name__=="__main__":
    wishMe()
    while(True):
        query=takeCommand()
        query=query.lower()

        if "study" in query:
            speak("Study service onnnnn ")
            study()
        if "system" in query:
            speak("system service onnnnn")
            systemService()
        if( "web service" in query) or ("internet" in query):
            speak("Web service onnnnnn")
            webService()
        if ("sleep" in query):
            speak("Sleep onnnnn")
            time.sleep(10)
            speak("Ready and Active")
        if "exit" in query or "quit" in query :
            speak("Closing myself")
            winsound.PlaySound("SystemExit", winsound.SND_ALIAS)
            break
# Out:
# Listening  ....
# Recognizing  ....
# Listening  ....
# Recognizing  ....
# aapane miss kar diya to kya neurofeedback per a gaye
#
# Listening  ....
# Recognizing  ....
# kya bolenge se
#
# Listening  ....
# Recognizing  ....
# open web service
#
# Listening  ....
# Recognizing  ....
# web service country group mein Gupta Rahega aapse kamon laga ki aap kya karna chahie FIR
#
# Listening  ....
# Recognizing  ....
# 11th birthday Youtube open karna chahti YouTube
#
# Listening  ....
# Recognizing  ....
# Youtube Youtube ko open kar dega Itna logi case mein
#
# Listening  ....
# Recognizing  ....
# is logic pay kam karta hai
#
# Listening  ....
# Recognizing  ....
# lekin abhi chalta Rahega Lekin usmein
#
# Listening  ....
# Recognizing  ....
# infant group se bahar Ho To Ham Kya Karenge
#
# Listening  ....
# Recognizing  ....
# sleep Jarvis
#
# Listening  ....
# Recognizing  ....
# kabhi kabhi time lagta hai lekin Aisa time
#
# Listening  ....
# Recognizing  ....
# Agar Hamen functions exit karna hai Kyunki abhi look Mein ghumta aaega to aap kya bolenge
#
# Listening  ....
# Recognizing  ....
# system service
#
# Listening  ....
# Recognizing  ....
# Tu Agar bola to is system service ke andar pahunch chuka hai aap Shayad main yaar
#
# Listening  ....
# Recognizing  ....
# Sabhi web service system service Kaise
#
# Listening  ....
# Recognizing  ....
# abhi a chuka system service ke andar Kyunki Main abhi system service command bus ke andar kya hai agar aap ke andar aapko aapke
#
# Listening  ....
# Recognizing  ....
# so agar mein se bolo
#
# Listening  ....
# Recognizing  ....
# band kar diya aur FIR WhatsApp ko open
#
# Listening  ....
# Recognizing  ....
# to usne WhatsApp open kar diya hai to ISI Tarah Kaise aapko Agar Kuchh aur open karna hai to office se open kar paoge
#
# Listening  ....
# Recognizing  ....
# setting setting Chota Gujari
#
# Listening  ....
# Recognizing  ....
# aap Ham Karenge exit exit
#
# Listening  ....
# Recognizing  ....
# study service wala
#
# Listening  ....
# Recognizing  ....
# Listening  ....
# Recognizing  ....
# FB Lite
#
# Listening  ....
# Recognizing  ....
# Apni To aap kya karoge kya book ka naam Dal Dena aur uska adress Dal Dena kahan President to aap use kar paoge
#
# Listening  ....
# Recognizing  ....
# yah Tha Mera Jarvis project I hope aap ko ek Pasand Aaya Hoga se kam karta hai ismein bahut sare ki
#
# Listening  ....
# Recognizing  ....
# Listening  ....
# Recognizing  ....
# video
#
# Listening  ....
# Recognizing  ....
# band kar diya
#
# Listening  ....
# Recognizing  ....
# chalu hai
#
# Listening  ....
# Recognizing  ....
# Listening  ....
# Recognizing  ....
# exit marriage
#
# Listening  ....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-ba2a8642bb13> in <module>
#     260     wishMe()
#     261     while(True):
# --> 262         query=takeCommand()
#     263         query=query.lower()
#     264
#
# <ipython-input-7-ba2a8642bb13> in takeCommand()
#      34         print("Listening  ....")
#      35         recogniz.pause_threshold=0.5
# ---> 36         audio=recogniz.listen(source)
#      37     try:
#      38         print("Recognizing  ....")
#
# c:\Users\HP\anaconda3\lib\site-packages\speech_recognition\__init__.py in listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     650                     break
#     651
# --> 652                 buffer = source.stream.read(source.CHUNK)
#     653                 if len(buffer) == 0: break  # reached end of the stream
#     654                 frames.append(buffer)
#
# c:\Users\HP\anaconda3\lib\site-packages\speech_recognition\__init__.py in read(self, size)
#     159
#     160         def read(self, size):
# --> 161             return self.pyaudio_stream.read(size, exception_on_overflow=False)
#     162
#     163         def close(self):
#
# c:\Users\HP\anaconda3\lib\site-packages\pyaudio.py in read(self, num_frames, exception_on_overflow)
#     606                           paCanNotReadFromAnOutputOnlyStream)
#     607
# --> 608         return pa.read_stream(self._stream, num_frames, exception_on_overflow)
#     609
#     610     def get_read_available(self):
#
# KeyboardInterrupt:
